# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephChennattu123/UDS_OCR/blob/main/UDS_OCR_TEIL2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-docx

import os
from google.colab import drive
from docx import Document

drive.mount('/content/gdrive', force_remount=True)

def find_txt_file_with_pattern(directory, pattern="Abzug_fuer_KI"):
    for filename in os.listdir(directory):
        if pattern in filename and filename.endswith(".txt"):
            return os.path.join(directory, filename)
    return None

def load_data_from_txt(txt_file_path):
    data_dict = {}
    with open(txt_file_path, 'r',encoding='windows-1252') as file:
        for line in file:
            line = line.strip().split(";")
            if len(line) == 4:
                eighteen_number = line[0].strip()
                four500_number = line[1].strip() if len(line[1].strip()) == 10 else "X"
                creditor_number = line[2].strip() if len(line[2].strip()) == 6 else "X"
                company_name = line[3].strip() if line[3].strip() else "X"
                data_dict[eighteen_number] = {
                    '4500_number': four500_number,
                    'creditor_number': creditor_number,
                    'company_name': company_name
                }
    return data_dict

def process_table_and_rename_pdfs(word_file_path, data_dict):
    document = Document(word_file_path)
    table = document.tables[0]

    for row in table.rows[1:]:  # Skip header row
        eighteen_ocr_result = row.cells[2].text.strip()
        zw_ocr_result = row.cells[3].text.strip()
        pdf_file_path = row.cells[4].text.strip()

        if eighteen_ocr_result in data_dict:
            four500_number = data_dict[eighteen_ocr_result].get('4500_number', 'X')
            creditor_number = data_dict[eighteen_ocr_result].get('creditor_number', 'X')
            company_name = data_dict[eighteen_ocr_result].get('company_name', 'X')
        else:
            four500_number = "X"
            creditor_number = "X"
            company_name = "X"

        if os.path.exists(pdf_file_path):
            new_file_path = rename_pdf_file(
                pdf_file_path,
                creditor_number,
                eighteen_ocr_result,
                zw_ocr_result,
                four500_number,
                company_name
            )
            # Update the file path in the table
            row.cells[4].text = new_file_path

    # Save the updated document
    document.save(word_file_path)
    print(f"Updated .docx file saved at: {word_file_path}")

def rename_pdf_file(pdf_file_path, creditor_number, eighteen_ocr_result, zw_ocr_result, four500_number, company_name):
    directory = os.path.dirname(pdf_file_path)
    base_name = f"{creditor_number}_{eighteen_ocr_result}_{zw_ocr_result}_{four500_number}_{company_name}"
    extension = ".pdf"
    new_file_path = os.path.join(directory, base_name + extension)
    counter = 1

    # Check if the file exists
    if not os.path.exists(pdf_file_path):
        print(f"File not found: {pdf_file_path}. Skipping.")
        return pdf_file_path

    # Ensure unique file name
    while os.path.exists(new_file_path):
        new_file_path = os.path.join(directory, f"{base_name}_{counter}{extension}")
        counter += 1

    os.rename(pdf_file_path, new_file_path)
    print(f"File '{pdf_file_path}' renamed to: {new_file_path}")
    return new_file_path  # Return the new file path for updating the .docx


word_file_path = "/content/gdrive/My Drive/processed_files_with_images.docx"
directory_path = "/content/gdrive/My Drive/"

# Find the .txt file with the specific pattern
txt_file_path = find_txt_file_with_pattern(directory_path)

# Check if the file was found and proceed with processing
if txt_file_path:
    print(f"Found .txt file: {txt_file_path}")
    data_dict = load_data_from_txt(txt_file_path)
    process_table_and_rename_pdfs(word_file_path, data_dict)
else:
    print(f"No .txt file found with pattern 'Abzug_fuer_KI' in {directory_path}")
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (5.3.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.12.2)
# Mounted at /content/gdrive
# Found .txt file: /content/gdrive/My Drive/Abzug_fuer_KI .txt
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__1.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_1.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__2.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_2.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__3.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_3.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__4.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_4.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__5.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_5.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__6.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_6.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__7.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_7.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__8.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_8.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__9.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_9.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__10.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_10.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__11.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_11.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__12.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_12.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__13.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_13.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__14.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_14.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__15.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_15.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__16.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_16.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__17.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_17.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__18.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_18.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_1_X_X.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__19.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_19.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__20.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_20.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__21.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_21.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_1__1.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_1_X_X_1.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__22.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_22.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__23.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_23.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__24.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_24.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__25.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_25.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__26.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_26.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__27.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_27.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__28.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_28.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__29.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_29.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__30.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_30.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__31.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_31.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824016020_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/279710_1824016020_1_4500266219_VI HALBLEITERMATERIAL GMBH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824016018_X_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/246905_1824016018_X_4500266345_ProfiLab24 GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824016016_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/246905_1824016016_3_4500265857_ProfiLab24 GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015284_X_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/278762_1824015284_X_4500261739_Knowunity GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015082_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/207895_1824015082_1_4500264722_Bio-Rad Laboratories GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015975_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/204453_1824015975_3_4500267158_METTLER-TOLEDO GMBH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__32.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_32.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_3_X_X.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__33.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_33.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_X__34.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_X_X_X_34.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015000_X_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_1824015000_X_X_X.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015550_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/205342_1824015550_3_4500265720_Regler Office GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015084_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/241802_1824015084_1_4500257286_SSG Saar-Service GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015358_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/206195_1824015358_3_4500258497_Energie SaarLorLux AG.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015059_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/228890_1824015059_3_4500266249_hygi.de GmbH & Co. KG.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015960_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/208475_1824015960_3_4500267070_Air Liquide Deutschland GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015962_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/204100_1824015962_3_4500267264_Linde GmbH Gases Division.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015969_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/204100_1824015969_3_4500267265_Linde GmbH Gases Division.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015367_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/205342_1824015367_3_4500265036_Regler Office GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015971_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/204100_1824015971_3_4500267265_Linde GmbH Gases Division.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015970_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/204100_1824015970_3_4500267265_Linde GmbH Gases Division.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015975_3__1.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/204453_1824015975_3_4500267158_METTLER-TOLEDO GMBH_1.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824013741_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/208872_1824013741_3_4500264915_Leibniz-Institut DSMZ GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015044_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/204100_1824015044_1_4500266736_Linde GmbH Gases Division.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824011843_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/279200_1824011843_1_4500264082_LINQ management GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824005344_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/234731_1824005344_1_4500181073_IKS BgA EDV-Dienstleistung.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824013346_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824013346_3_4500265486_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824005047_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/711264_1824005047_1_4500260570_BioLegend Europe B.V.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015048_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/220907_1824015048_3_4500257819_HTS GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824016934_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_1824016934_3_X_X.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824013705_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/208475_1824013705_1_4500265670_Air Liquide Deutschland GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015036_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/206534_1824015036_3_4500266123_N. Toussaint & Co. GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015037_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/205512_1824015037_3_4500266590_Carl Roth GmbH + Co. KG.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824005038_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824005038_1_4500260321_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824013789_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/205512_1824013789_3_4500265280_Carl Roth GmbH + Co. KG.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015916_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/278923_1824015916_3_4500264218_Stölting Facility + Service Südwest.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_1__2.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_1_X_X_2.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015088_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/255984_1824015088_1_4500252815_EPI Lothar Eisenhauer.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_3__1.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_3_X_X_1.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_3__2.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_3_X_X_2.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015917_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/201445_1824015917_1_4500265692_DEUTERO GMBH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015318_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/274889_1824015318_3_4500265845_3D Prima Techn. Deutschl. GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015919_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824015919_1_4500266454_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015920_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824015920_3_4500266454_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015922_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824015922_3_4500266887_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015923_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824015923_1_4500266792_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015924_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824015924_3_4500266792_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_X_1__3.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/X_X_1_X_X_3.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015900_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/212441_1824015900_1_4500267067_Fisher Scientific GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015109_1_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/202572_1824015109_1_4500266726_GREINER Bio-One GmbH.pdf
# File '/content/gdrive/My Drive/Neue Rechnungen/_1824015910_3_.pdf' renamed to: /content/gdrive/My Drive/Neue Rechnungen/205208_1824015910_3_4500266700_QIAGEN GMBH.pdf
# Updated .docx file saved at: /content/gdrive/My Drive/processed_files_with_images.docx
